# %% [markdown]
# <a href="https://colab.research.google.com/github/RickPardono/An-lise-de-dados-sobre-a-degrada-o-da-Floresta-Amaz-nica-Brasileira/blob/main/Scripts_Cap1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importando as bibliotecas e comando %matplotlib:
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
# Carregando arquivo no notebook e fazendo a leitura:
def_amazon_data = pd.read_csv('/content/def_area_2004_2019.csv')

# %%
# Exibindo o cabeçalho do Dataframe:
def_amazon_data.head()
# Out:
#    Ano/Estados   AC    AM   AP    MA     MT    PA    RO   RR   TO  AMZ LEGAL
# 0         2004  728  1232   46   755  11814  8870  3858  311  158      27772
# 1         2005  592   775   33   922   7145  5899  3244  133  271      19014
# 2         2006  398   788   30   674   4333  5659  2049  231  124      14286
# 3         2007  184   610   39   631   2678  5526  1611  309   63      11651
# 4         2008  254   604  100  1271   3258  5607  1136  574  107      12911

# %%
# Renomeando a primeira e a última coluna para melhor entendimento:
def_amazon_data = def_amazon_data.rename(columns={'Ano/Estados': 'Ano', 'AMZ LEGAL': 'Total'})

# %%
# Exibindo o cabeçalho do Dataframe após as 2 colunas serem renomeadas:
def_amazon_data.head()
# Out:
#     Ano   AC    AM   AP    MA     MT    PA    RO   RR   TO  Total
# 0  2004  728  1232   46   755  11814  8870  3858  311  158  27772
# 1  2005  592   775   33   922   7145  5899  3244  133  271  19014
# 2  2006  398   788   30   674   4333  5659  2049  231  124  14286
# 3  2007  184   610   39   631   2678  5526  1611  309   63  11651
# 4  2008  254   604  100  1271   3258  5607  1136  574  107  12911

# %%
# Foi verificado que o Dataset não apresenta valores nulos ao utilizar o comando: 
def_amazon_data.isnull().sum()
# Out:
# Ano      0
# AC       0
# AM       0
# AP       0
# MA       0
# MT       0
# PA       0
# RO       0
# RR       0
# TO       0
# Total    0
# dtype: int64

# %%
# plotando as áreas totais devastadas através dos anos:
plt.figure(figsize=(12,8))
plt.suptitle('Área total desmatada por ano na Amazônia', fontsize=14, weight='bold')
plt.subplot(2,1,1)
plt.bar(def_amazon_data.Ano, def_amazon_data.Total, color='b', alpha=0.6)
plt.ylabel('Total',fontsize=14)
plt.xticks(def_amazon_data.Ano)

plt.subplot(2,1,2)
plt.plot(def_amazon_data.Ano, def_amazon_data.Total)
plt.xlabel('Ano', fontsize=14)
plt.ylabel('Total',fontsize=14)
plt.xticks(def_amazon_data.Ano)
fig = plt.gcf()
plt.savefig('grafico1.png', format='png')
plt.show()

# %%
# Plotando a soma da área desmatada total para cada estado e para todos os anos no conjunto de dados:
states=["AC","AM","AP","MA","MT","PA","RO","RR","TO"]
data=[]
for i in range(len(states)):
    data.append(def_amazon_data[states[i]].sum())
plt.figure(figsize=(12,4))
plt.suptitle('Área total desmatada por estado', fontsize=14, weight='bold')
plt.bar(states, data, color='darkolivegreen',alpha=1.0)
plt.xlabel('Estados', fontsize=14)
plt.ylabel('Total',fontsize=14)
fig = plt.gcf()
plt.savefig('grafico2.png', format='png')
plt.show()

# %%
# Plotando a área desmatada anualmente por estado de 2004 a 2019:
states=["AC","AM","AP","MA","MT","PA","RO","RR","TO"]
fig, ax = plt.subplots(3, 3, figsize=(15,10))
plt.suptitle('Área amazônica desmatada anualmente por estado - 2004 a 2019', fontsize=15, weight='bold')
plt.subplots_adjust(wspace=0.3, hspace=0.5)
col_names = def_amazon_data.columns[1:10]
for i in range(3):
    for j in range(3):
        col = col_names[i*3+j]
        ax[i,j].plot(def_amazon_data['Ano'], def_amazon_data[col], linewidth=2, color='forestgreen')
        ax[i,j].set_ylabel('Área em $km^2$', fontsize=12)
        ax[i,j].set_title(states[i*3+j])
        ax[i,j].grid(axis='y', color='0.95')
        ax[i,j].xaxis.set_major_locator(plt.MaxNLocator(integer=True))
        if (j>0):
             ax[i,j].set(ylabel='')
fig = plt.gcf()
plt.savefig('grafico3.png', format='png')
